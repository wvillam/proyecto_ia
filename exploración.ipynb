# %% [markdown]
# <a href="https://colab.research.google.com/github/wvillam/proyecto_ia/blob/main/exploraci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
#Crear carpeta oculta en root .kaggle
# !mkdir ~/.kaggle

#Cargar el archivo .json con el API Token
files._upload_file(filepath=r"/root/.kaggle/kaggle.json")

#Hacer la carpeta privada
# !chmod 600 ~/.kaggle/kaggle.json

#Eliminar carpeta sample_data y archivos de ejemplo
# !rm -rf sample_data
# Out:
#      <input type="file" id="files-faf28561-7cd0-42b4-a385-651cd56f78e4" name="files[]"  disabled
#         style="border:none" />
#      <output id="result-faf28561-7cd0-42b4-a385-651cd56f78e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# /**
# ...

# %%
#Descargar archivos de la competición
# !kaggle competitions download -c udea-ai4eng-20242
#Descomprimir archivo
# !unzip udea-ai4eng-20242.zip
#Eliminar archivo .zip
# !rm udea-ai4eng-20242.zip
#Eliminar Archivos de ejemplo
# !rm submission_example.csv
# !rm test.csv
# Out:
# ...
#  89% 18.0M/20.1M [00:01<00:00, 14.9MB/s]
# 100% 20.1M/20.1M [00:01<00:00, 11.8MB/s]
# Archive:  udea-ai4eng-20242.zip
#   inflating: submission_example.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd

df= pd.read_csv("train.csv")
df
# Out:
#             ID  PERIODO                  ESTU_PRGM_ACADEMICO  \
# 0       904256    20212                           ENFERMERIA
# 1       645256    20212                              DERECHO
# 2       308367    20203                MERCADEO Y PUBLICIDAD
# 3       470353    20195           ADMINISTRACION DE EMPRESAS
# 4       989032    20212                           PSICOLOGIA
# ...        ...      ...                                  ...
# 692495   25096    20195                             BIOLOGIA
# 692496  754213    20212                           PSICOLOGIA
# 692497  504185    20183  ADMINISTRACIÓN EN SALUD OCUPACIONAL
# 692498  986620    20195                           PSICOLOGIA
# 692499  933374    20195                           PSICOLOGIA
#
#        ESTU_PRGM_DEPARTAMENTO            ESTU_VALORMATRICULAUNIVERSIDAD  \
# 0                      BOGOTÁ  Entre 5.5 millones y menos de 7 millones
# 1                   ATLANTICO  Entre 2.5 millones y menos de 4 millones
# ...

# %%
#Lectura de datos mostrando el conteo de programas académicos por departamento
df.groupby("ESTU_PRGM_DEPARTAMENTO")["ESTU_PRGM_ACADEMICO"].count()
# Out:
# ESTU_PRGM_DEPARTAMENTO
# AMAZONAS               40
# ANTIOQUIA           83607
# ARAUCA                589
# ATLANTICO           41020
# BOGOTÁ             282159
# BOLIVAR             20629
# BOYACA              14048
# CALDAS              11640
# CAQUETA              2659
# CASANARE             1852
# CAUCA               11471
# CESAR                8279
# CHOCO                4289
# CORDOBA             12188
# CUNDINAMARCA        14018
# GUAVIARE               37
# HUILA                9995
# LA GUAJIRA           4778
# MAGDALENA            9512
# META                 7910
# NARIÑO              13454
# NORTE SANTANDER     22588
# PUTUMAYO              795
# QUINDIO              8229
# RISARALDA           12679
# SAN ANDRES             10
# SANTANDER           28828
# SUCRE                8674
# TOLIMA              11921
# VALLE               44588
# VAUPES                 14
# Name: ESTU_PRGM_ACADEMICO, dtype: int64
